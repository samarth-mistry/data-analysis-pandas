# %% [markdown]
# <a href="https://colab.research.google.com/github/samarth-mistry/data-analysis-pandas/blob/main/TextManipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
chicago = pd.read_csv("https://raw.githubusercontent.com/samarth-mistry/csv-data/main/pandas/chicago.csv")
chicago.head(3)
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1002.1+ KB

# %%
chicago.nunique()
chicago["Department"] = chicago["Department"].astype('category')
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 784.2+ KB

# %% [markdown]
# lower upper title len

# %%
chicago["Name"].str.lower()
# Out:
# 0            aaron,  elvia j
# 1          aaron,  jeffery m
# 2             aaron,  karina
# 3        aaron,  kimberlei r
# 4        abad jr,  vicente m
#                 ...
# 32058     zygowicz,  peter j
# 32059      zymantas,  mark e
# 32060    zyrkowski,  carlo e
# 32061    zyskowski,  dariusz
# 32062                    NaN
# Name: Name, Length: 32063, dtype: object

# %%
chicago = pd.read_csv("https://raw.githubusercontent.com/samarth-mistry/csv-data/main/pandas/chicago.csv").dropna(how="all")
chicago.head(3)
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1.2+ MB

# %%
# chicago["Department"]
chicago["Department"]=chicago["Department"].str.replace("MGMNT","MANGEMENT")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER   WATER MANGEMENT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV   WATER MANGEMENT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago["Employee Annual Salary"].str.replace("$","").astype('float')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0         90744.0
# 1         84450.0
# 2         84450.0
# 3         89880.0
# 4        106836.0
#            ...
# 32057     99528.0
# 32058     87384.0
# 32059     84450.0
# 32060     87384.0
# 32061    113664.0
# Name: Employee Annual Salary, Length: 32062, dtype: float64

# %%
chicago["Position Title"]
chicago["Position Title"].str.lower()
mask=chicago["Position Title"].str.lower().str.contains('water')
chicago[mask]
# Out:
#                        Name                                 Position Title  \
# 0           AARON,  ELVIA J                               WATER RATE TAKER
# 554      ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671         ANDER,  PERRY A                               WATER CHEMIST II
# 685     ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702       ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# ...                     ...                                            ...
# 29669        VERMA,  ANUPAM           MANAGING ENGINEER - WATER MANAGEMENT
# 30239   WASHINGTON,  JOSEPH                              WATER CHEMIST III
# 30544       WEST,  THOMAS R                   GEN SUPT OF WATER MANAGEMENT
# 30991    WILLIAMS,  MATTHEW             FOREMAN OF WATER PIPE CONSTRUCTION
# 31405  WOODRIDGE,  ROBERT L             FOREMAN OF WATER PIPE CONSTRUCTION
#
#             Department Employee Annual Salary
# ...

# %%
chicago[chicago["Position Title"].str.lower().str.startswith('water')]
# Out:
#                          Name           Position Title       Department  \
# 0             AARON,  ELVIA J         WATER RATE TAKER  WATER MANGEMENT
# 671           ANDER,  PERRY A         WATER CHEMIST II  WATER MANGEMENT
# 1054         ASHLEY,  KARMA T         WATER CHEMIST II  WATER MANGEMENT
# 1079        ATKINS,  JOANNA M         WATER CHEMIST II  WATER MANGEMENT
# 1181       AZEEM,  MOHAMMED A         WATER CHEMIST II  WATER MANGEMENT
# ...                       ...                      ...              ...
# 28574      THREATT,  DENISE R  WATER QUALITY INSPECTOR  WATER MANGEMENT
# 28602       TIGNOR,  DARRYL B         WATER RATE TAKER  WATER MANGEMENT
# 28955  TRAVIS COOK,  LESLIE R         WATER RATE TAKER  WATER MANGEMENT
# 29584        VELAZQUEZ,  JOHN         WATER RATE TAKER  WATER MANGEMENT
# 30239     WASHINGTON,  JOSEPH        WATER CHEMIST III  WATER MANGEMENT
#
#       Employee Annual Salary
# 0                  $90744.00
# 671                $82044.00
# ...

# %%
mask=chicago["Position Title"].str.lower().str.endswith('ist')
chicago[mask]
# Out:
#                           Name                        Position Title  \
# 184             AFROZ,  NAYYAR                          PSYCHIATRIST
# 308           ALARCON,  LUIS J            LOAN PROCESSING SPECIALIST
# 422           ALLAIN,  CAROLYN  SENIOR TELECOMMUNICATIONS SPECIALIST
# 472             ALLEN,  ROBERT                             MACHINIST
# 705        ANDERSON,  EDWARD M             SR PROCUREMENT SPECIALIST
# ...                        ...                                   ...
# 31667         YODER,  TERESA G                   ARCHIVAL SPECIALIST
# 31688  YOUNGBLOOM,  LAURENCE G        CRIMES SURVEILLANCE SPECIALIST
# 31717       YOUNG,  KIMBERLY M             SR PROCUREMENT SPECIALIST
# 31837            ZAPATA,  HUGO             SR PROCUREMENT SPECIALIST
# 31918        ZEMKE,  RICHARD P                             MACHINIST
#
#                   Department Employee Annual Salary
# 184                   HEALTH              $99840.00
# ...

# %% [markdown]
# strip lstrip and rstrip

# %%
"   Hello  ".lstrip()
"   Hello  ".rstrip()
"   Hello  ".strip()
# Out:
# 'Hello'

# %%
chicago["Name"]=chicago["Name"].str.strip()
chicago.head(3)
# Out:
#                 Name    Position Title       Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MANGEMENT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER           POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER           POLICE              $84450.00

# %%
chicago["Position Title"]=chicago["Position Title"].str.lstrip().str.rstrip()
chicago.head(3)
# Out:
#                 Name    Position Title       Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MANGEMENT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER           POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER           POLICE              $84450.00

# %%
chicago = pd.read_csv("https://raw.githubusercontent.com/samarth-mistry/csv-data/main/pandas/chicago.csv").dropna(how="all")
chicago["Department"]=chicago["Department"].astype('category')
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.index
chicago.index=chicago.index.str.strip().str.title()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-9d84c363ea8b> in <module>()
#       1 chicago.index
# ----> 2 chicago.index=chicago.index.str.strip().str.title()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings/accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
# ...

# %%
chicago.columns=chicago.columns.str.upper()

# %%
#SPLIT
"Hello my name is Samarth".split(" ")
# Out:
# ['Hello', 'my', 'name', 'is', 'Samarth']

# %%
chicago["Name"].str.split(',').str.get(0).str.title().value_counts()
# Out:
# Williams     293
# Johnson      244
# Smith        241
# Brown        185
# Jones        183
#             ...
# Horkavy        1
# Horn           1
# Horne Jr       1
# Horner         1
# Zyskowski      1
# Name: Name, Length: 13829, dtype: int64

# %%
chicago["Position Title"].str.split(" ").str.get(0).value_counts()
# Out:
# POLICE             10856
# FIREFIGHTER-EMT     1509
# SERGEANT            1186
# POOL                 918
# FIREFIGHTER          810
#                    ...
# DENTIST                1
# ASSOC                  1
# TELEPHONE              1
# MAYOR                  1
# PREPRESS               1
# Name: Position Title, Length: 320, dtype: int64

# %%
chicago["Name"].str.split(",").str.get(1).str.strip().str.split(" ").str.get(0).value_counts()
# Out:
# MICHAEL     1153
# JOHN         899
# JAMES        676
# ROBERT       622
# JOSEPH       537
#             ...
# DEENA          1
# CHERRISE       1
# EARTHA         1
# ERNIKA         1
# MAC            1
# Name: Name, Length: 5091, dtype: int64

# %%
chicago[["First Name","Last Name"]]=chicago["Name"].str.split(',',expand=True)
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00
#
#   First Name    Last Name
# 0      AARON      ELVIA J
# 1      AARON    JEFFERY M
# 2      AARON       KARINA
