# %% [markdown]
# <a href="https://colab.research.google.com/github/samarth-mistry/data-analysis-pandas/blob/main/DataFrames_1_basics_evrlyt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
players = pd.read_csv("https://raw.githubusercontent.com/samarth-mistry/csv-data/main/pandas/nba.csv")
players
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# Intro to dataframe

# %% [markdown]
# PD converted all int to float due to NaN

# %%
nba = players
nba.head()
nba.index
nba.shape
nba.dtypes
nba.columns
nba.axes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# common methods in series n DF

# %%
revenue = pd.read_csv("https://raw.githubusercontent.com/samarth-mistry/csv-data/main/pandas/revenue.csv")
revenue
# Out:
#       Date  New York  Los Angeles  Miami
# 0   1/1/16       985          122    499
# 1   1/2/16       738          788    534
# 2   1/3/16        14           20    933
# 3   1/4/16       730          904    885
# 4   1/5/16       114           71    253
# 5   1/6/16       936          502    497
# 6   1/7/16       123          996    115
# 7   1/8/16       935          492    886
# 8   1/9/16       846          954    823
# 9  1/10/16        54          285    216

# %%
rev = revenue
rev.sum()
rev.sum(axis = 'columns') #rev.sum(axis = 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0    1606
# 1    2060
# 2     967
# 3    2519
# 4     438
# 5    1935
# 6    1234
# 7    2313
# 8    2623
# 9     555
# dtype: int64

# %% [markdown]
# Sel1 col from DF

# %%
nba.Name
type(nba.Name)
nba["Name"]
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba[["Name","Team"]]   #order maintained in new DF

sel_columns = ['Salary','Team',"Name"]
nba[sel_columns].head()
# Out:
#       Salary            Team           Name
# 0  7730337.0  Boston Celtics  Avery Bradley
# 1  6796117.0  Boston Celtics    Jae Crowder
# 2        NaN  Boston Celtics   John Holland
# 3  1148640.0  Boston Celtics    R.J. Hunter
# 4  5000000.0  Boston Celtics  Jonas Jerebko

# %% [markdown]
# Add new column

# %%
nba["Sport"] = "Basketball"
nba.head()
#specific loc
nba.insert(loc=3,column="League",value="National Basketball")
nba.head()
# Out:
#             Name            Team  Number               League Position   Age  \
# 0  Avery Bradley  Boston Celtics     0.0  National Basketball       PG  25.0
# 1    Jae Crowder  Boston Celtics    99.0  National Basketball       SF  25.0
# 2   John Holland  Boston Celtics    30.0  National Basketball       SG  27.0
# 3    R.J. Hunter  Boston Celtics    28.0  National Basketball       SG  22.0
# 4  Jonas Jerebko  Boston Celtics     8.0  National Basketball       PF  29.0
#
#   Height  Weight            College     Salary       Sport
# 0    6-2   180.0              Texas  7730337.0  Basketball
# 1    6-6   235.0          Marquette  6796117.0  Basketball
# 2    6-5   205.0  Boston University        NaN  Basketball
# 3    6-5   185.0      Georgia State  1148640.0  Basketball
# 4   6-10   231.0                NaN  5000000.0  Basketball

# %% [markdown]
# create new col from existing

# %%
nba["Age after Decade"] = nba["Age"]+10
nba.head()
nba["Salary"] - 5000000
nba["New Salary"] = nba["Salary"].sub(500000)
nba.head()
# Out:
#             Name            Team  Number               League Position   Age  \
# 0  Avery Bradley  Boston Celtics     0.0  National Basketball       PG  25.0
# 1    Jae Crowder  Boston Celtics    99.0  National Basketball       SF  25.0
# 2   John Holland  Boston Celtics    30.0  National Basketball       SG  27.0
# 3    R.J. Hunter  Boston Celtics    28.0  National Basketball       SG  22.0
# 4  Jonas Jerebko  Boston Celtics     8.0  National Basketball       PF  29.0
#
#   Height  Weight            College     Salary       Sport  Age after Decade  \
# 0    6-2   180.0              Texas  7730337.0  Basketball              35.0
# 1    6-6   235.0          Marquette  6796117.0  Basketball              35.0
# 2    6-5   205.0  Boston University        NaN  Basketball              37.0
# 3    6-5   185.0      Georgia State  1148640.0  Basketball              32.0
# 4   6-10   231.0                NaN  5000000.0  Basketball              39.0
#
#    New Salary
# 0   7230337.0
# ...

# %%
nba["Weight in Kg"] = nba["Weight"].mul(0.4535)
nba.head()
# Out:
#             Name            Team  Number               League Position   Age  \
# 0  Avery Bradley  Boston Celtics     0.0  National Basketball       PG  25.0
# 1    Jae Crowder  Boston Celtics    99.0  National Basketball       SF  25.0
# 2   John Holland  Boston Celtics    30.0  National Basketball       SG  27.0
# 3    R.J. Hunter  Boston Celtics    28.0  National Basketball       SG  22.0
# 4  Jonas Jerebko  Boston Celtics     8.0  National Basketball       PF  29.0
#
#   Height  Weight            College     Salary       Sport  Age after Decade  \
# 0    6-2   180.0              Texas  7730337.0  Basketball              35.0
# 1    6-6   235.0          Marquette  6796117.0  Basketball              35.0
# 2    6-5   205.0  Boston University        NaN  Basketball              37.0
# 3    6-5   185.0      Georgia State  1148640.0  Basketball              32.0
# 4   6-10   231.0                NaN  5000000.0  Basketball              39.0
#
#    New Salary  Weight in Kg
# ...

# %%
nba["Position"].value_counts()
nba["Position"].value_counts(normalize=True)*100
# Out:
# SG    22.319475
# PF    21.881838
# PG    20.131291
# SF    18.599562
# C     17.067834
# Name: Position, dtype: float64

# %% [markdown]
# dropna funct

# %%
nba.dropna()
# Out:
#               Name            Team  Number               League Position  \
# 0    Avery Bradley  Boston Celtics     0.0  National Basketball       PG
# 1      Jae Crowder  Boston Celtics    99.0  National Basketball       SF
# 3      R.J. Hunter  Boston Celtics    28.0  National Basketball       SG
# 6    Jordan Mickey  Boston Celtics    55.0  National Basketball       PF
# 7     Kelly Olynyk  Boston Celtics    41.0  National Basketball        C
# ..             ...             ...     ...                  ...      ...
# 449    Rodney Hood       Utah Jazz     5.0  National Basketball       SG
# 451  Chris Johnson       Utah Jazz    23.0  National Basketball       SF
# 452     Trey Lyles       Utah Jazz    41.0  National Basketball       PF
# 453   Shelvin Mack       Utah Jazz     8.0  National Basketball       PG
# 456    Jeff Withey       Utah Jazz    24.0  National Basketball        C
#
#       Age Height  Weight        College     Salary       Sport  \
# ...

# %%
nba.dropna(how="any") #del when any1 is NaN
nba.dropna(how="all") 
#for specific col
nba.dropna(subset=['College']) #if col is NaN it's gone
# Out:
#               Name            Team  Number               League Position  \
# 0    Avery Bradley  Boston Celtics     0.0  National Basketball       PG
# 1      Jae Crowder  Boston Celtics    99.0  National Basketball       SF
# 2     John Holland  Boston Celtics    30.0  National Basketball       SG
# 3      R.J. Hunter  Boston Celtics    28.0  National Basketball       SG
# 4    Jonas Jerebko  Boston Celtics     8.0  National Basketball       PF
# ..             ...             ...     ...                  ...      ...
# 453   Shelvin Mack       Utah Jazz     8.0  National Basketball       PG
# 454      Raul Neto       Utah Jazz    25.0  National Basketball       PG
# 455   Tibor Pleiss       Utah Jazz    21.0  National Basketball        C
# 456    Jeff Withey       Utah Jazz    24.0  National Basketball        C
# 457            NaN             NaN     NaN  National Basketball      NaN
#
#       Age Height  Weight            College     Salary       Sport  \
# ...

# %% [markdown]
# fillna

# %%
# nba.fillna(0) #all nan in DF is replaced by 0
nba = players.copy()
nba.tail()
# nba["College"].fillna("Unknown",inplace=True) #inplace is not recc
nba["College"] = nba["College"].fillna("Unknown")
nba.tail()
# Out:
#              Name       Team  Number               League Position   Age  \
# 453  Shelvin Mack  Utah Jazz     8.0  National Basketball       PG  26.0
# 454     Raul Neto  Utah Jazz    25.0  National Basketball       PG  24.0
# 455  Tibor Pleiss  Utah Jazz    21.0  National Basketball        C  26.0
# 456   Jeff Withey  Utah Jazz    24.0  National Basketball        C  26.0
# 457           NaN        NaN     NaN  National Basketball      NaN   NaN
#
#     Height  Weight  College     Salary       Sport  Age after Decade  \
# 453    6-3   203.0   Butler  2433333.0  Basketball              36.0
# 454    6-1   179.0  Unknown   900000.0  Basketball              34.0
# 455    7-3   256.0  Unknown  2900000.0  Basketball              36.0
# 456    7-0   231.0   Kansas   947276.0  Basketball              36.0
# 457    NaN     NaN  Unknown        NaN  Basketball               NaN
#
#      New Salary  Weight in Kg
# 453   1933333.0       92.0605
# 454    400000.0       81.1765
# ...

# %%
#ASTYPE
nba = pd.read_csv("https://raw.githubusercontent.com/samarth-mistry/csv-data/main/pandas/nba.csv").dropna(how="all")
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba["Age"].hasnans
nba["Age"].astype("int")
nba["Age"] = nba["Age"].astype("int")
nba["Salary"].hasnans
nba["Salary"]=nba["Salary"].fillna("0")
nba["Salary"].astype("int")
# Out:
# 0      7730337
# 1      6796117
# 2            0
# 3      1148640
# 4      5000000
#         ...
# 452    2239800
# 453    2433333
# 454     900000
# 455    2900000
# 456     947276
# Name: Salary, Length: 457, dtype: int64

# %%
nba["Position"].nunique()
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    457 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 35.7+ KB

# %%
nba["Position"]=nba["Position"].astype('category')
nba.info() #RAM friendly
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    457 non-null    object
# dtypes: category(1), float64(2), int64(1), object(5)
# memory usage: 32.8+ KB

# %%
# nba["Name"].sort_values()
nba.sort_values(by="Name",ascending=False)
nba.sort_values("Age",ascending=False)
nba.sort_values(by="Salary",na_position="first")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-68c62cbbd65b> in <module>()
#       2 nba.sort_values(by="Name",ascending=False)
#       3 nba.sort_values("Age",ascending=False)
# ----> 4 nba.sort_values(by="Salary",na_position="first")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6269
#    6270             indexer = nargsort(
# -> 6271                 k, kind=kind, ascending=ascending, na_position=na_position, key=key
#    6272             )
#    6273         else:
#
# ...

# %%
nba = pd.read_csv("https://raw.githubusercontent.com/samarth-mistry/csv-data/main/pandas/nba.csv").dropna(how="all")
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.sort_values(by=['Team','Name'])
nba.sort_values(by=['Name','Team'],ascending=False)
nba.sort_values(by=['Name','Team'],ascending=[False, True])
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks    27.0        C  32.0   6-11
# 271    Zach Randolph       Memphis Grizzlies    50.0       PF  34.0    6-9
# 402      Zach LaVine  Minnesota Timberwolves     8.0       PG  21.0    6-5
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 386  Wilson Chandler          Denver Nuggets    21.0       SF  29.0    6-8
# ..               ...                     ...     ...      ...   ...    ...
# 312       Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
# 404    Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 328   Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 356     Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 152     Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
#
#      Weight         College      Salary
# ...

# %%
nba.sort_index()
nba.sort_index(ascending=False)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
#
#                College     Salary
# 456             Kansas   947276.0
# ...

# %%
nba["Salary"]=nba["Salary"].fillna(0).astype('int')
nba["Salary Rank"]=nba["Salary"].rank(ascending=False)
nba.sort_values("Salary",ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 273   Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 270   Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
#
#      Weight       College    Salary  Salary Rank
# ...
